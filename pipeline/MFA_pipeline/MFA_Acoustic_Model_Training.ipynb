# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
num_cores = os.cpu_count()
print(f"You have {num_cores} CPU cores available in this Colab session.")
# Out:
# You have 2 CPU cores available in this Colab session.

# %%
# %%writefile install_mfa.sh
# #!/bin/bash
#
# root_dir=${1:-/tmp/mfa}
# mkdir -p $root_dir
# cd $root_dir
#
# wget -q --show-progress https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# bash Miniconda3-latest-Linux-x86_64.sh -b -p $root_dir/miniconda3 -f
#
# $root_dir/miniconda3/bin/conda create -n aligner -c conda-forge montreal-forced-aligner -y
#
# echo -e "\n======== DONE =========="
# echo -e "\nTo activate MFA, run: source $root_dir/miniconda3/bin/activate aligner"
# echo -e "\nTo delete MFA, run: rm -rf $root_dir"
# echo -e "\nSee: https://montreal-forced-aligner.readthedocs.io/en/latest/aligning.html to know how to use MFA"
# Out:
# Writing install_mfa.sh

# %%
# download and install mfa
INSTALL_DIR="/tmp/mfa"

# !bash ./install_mfa.sh {INSTALL_DIR}
# !{INSTALL_DIR}/miniconda3/bin/conda run -n aligner conda install -c conda-forge llvm-openmp -y
# Out:
# Miniconda3-latest-L 100%[===================>] 147.45M   202MB/s    in 0.7s
# PREFIX=/tmp/mfa/miniconda3
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /tmp/mfa/miniconda3
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.1.1
#     latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /tmp/mfa/miniconda3/envs/aligner
#
#   added / updated specs:
#     - montreal-forced-aligner
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     adwaita-icon-theme-48.0    |           unix_0         596 KB  conda-forge
#     alsa-lib-1.2.13            |       hb9d3cd8_0         547 KB  conda-forge
#     aom-3.9.1                  |       hac33072_0         2.6 MB  conda-forge
#     at-spi2-atk-2.38.0         |       h0630a04_3         332 KB  conda-forge
#     at-spi2-core-2.40.3        |       h0630a04_0         643 KB  conda-forge
#     atk-1.0-2.38.0             |       h04ea711_2         348 KB  conda-forge
#     attr-2.5.1                 |       h166bdaf_1          69 KB  conda-forge
#     audioread-3.0.1            |  py311h38be061_2          44 KB  conda-forge
#     baumwelch-0.3.9            |       h434a139_3         368 KB  conda-forge
#     biopython-1.79             |  py311hd4cff14_3         3.2 MB  conda-forge
#     brotli-1.1.0               |       hb9d3cd8_2          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hb9d3cd8_2          18 KB  conda-forge
#     brotli-python-1.1.0        |  py311hfdbb021_2         342 KB  conda-forge
#     bzip2-1.0.8                |       h4bc722e_7         247 KB  conda-forge
#     ca-certificates-2025.1.31  |       hbcca054_0         154 KB  conda-forge
#     cairo-1.18.4               |       h3394656_0         955 KB  conda-forge
#     certifi-2025.1.31          |     pyhd8ed1ab_0         159 KB  conda-forge
#     cffi-1.17.1                |  py311hf29c0ef_0         295 KB  conda-forge
#     charset-normalizer-3.4.1   |     pyhd8ed1ab_0          46 KB  conda-forge
#     click-8.1.8                |     pyh707e725_0          83 KB  conda-forge
#     colorama-0.4.6             |     pyhd8ed1ab_1          26 KB  conda-forge
#     contourpy-1.3.1            |  py311hd18a35c_0         272 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
#     cyrus-sasl-2.1.27          |       h54b06d7_7         214 KB  conda-forge
#     dataclassy-1.0.1           |     pyhd8ed1ab_0          31 KB  conda-forge
#     dav1d-1.2.1                |       hd590300_0         742 KB  conda-forge
#     dbus-1.13.6                |       h5008d03_3         604 KB  conda-forge
#     decorator-5.2.1            |     pyhd8ed1ab_0          14 KB  conda-forge
#     epoxy-1.5.10               |       h166bdaf_1         1.4 MB  conda-forge
#     expat-2.7.0                |       h5888daf_0         137 KB  conda-forge
#     ffmpeg-7.1.1               | gpl_h0b79d52_704         9.9 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     fonttools-4.57.0           |  py311h2dc5d0c_0         2.8 MB  conda-forge
#     freetype-2.13.3            |       h48d6fc4_0         625 KB  conda-forge
#     fribidi-1.0.10             |       h36c2ea0_0         112 KB  conda-forge
#     gdk-pixbuf-2.42.12         |       hb9ae30d_0         516 KB  conda-forge
#     gettext-0.23.1             |       h5888daf_0         473 KB  conda-forge
#     gettext-tools-0.23.1       |       h5888daf_0         2.8 MB  conda-forge
#     glib-tools-2.84.1          |       h4833e2c_0         114 KB  conda-forge
#     gmp-6.3.0                  |       hac33072_2         449 KB  conda-forge
#     graphite2-1.3.13           |    h59595ed_1003          95 KB  conda-forge
#     graphviz-12.2.1            |       h5ae0cbf_1         2.3 MB  conda-forge
#     greenlet-3.1.1             |  py311hfdbb021_1         235 KB  conda-forge
#     gtk3-3.24.43               |       h0c6a113_5         5.3 MB  conda-forge
#     gts-0.7.6                  |       h977cf35_4         311 KB  conda-forge
#     h2-4.2.0                   |     pyhd8ed1ab_0          53 KB  conda-forge
#     harfbuzz-11.0.1            |       h2c12942_0         1.9 MB  conda-forge
#     hdbscan-0.8.39             |  py311h9f3472d_0         630 KB  conda-forge
#     hicolor-icon-theme-0.17    |       ha770c72_2          14 KB  conda-forge
#     hpack-4.1.0                |     pyhd8ed1ab_0          30 KB  conda-forge
#     hyperframe-6.1.0           |     pyhd8ed1ab_0          17 KB  conda-forge
#     icu-75.1                   |       he02047a_0        11.6 MB  conda-forge
#     idna-3.10                  |     pyhd8ed1ab_1          49 KB  conda-forge
#     importlib-metadata-8.6.1   |     pyha770c72_0          28 KB  conda-forge
#     jack-1.9.22                |       h7c63dc7_2         453 KB  conda-forge
#     joblib-1.4.2               |     pyhd8ed1ab_1         215 KB  conda-forge
#     kaldi-5.5.1112             |   cpu_hb028f0a_7        20.3 MB  conda-forge
#     kalpy-0.6.9                |  py311hd18a35c_0         3.1 MB  conda-forge
#     keyutils-1.6.1             |       h166bdaf_0         115 KB  conda-forge
#     kiwisolver-1.4.7           |  py311hd18a35c_0          71 KB  conda-forge
#     kneed-0.8.5                |     pyhd8ed1ab_1          15 KB  conda-forge
#     krb5-1.21.3                |       h659f571_0         1.3 MB  conda-forge
#     lame-3.100                 |    h166bdaf_1003         496 KB  conda-forge
#     lazy-loader-0.4            |     pyhd8ed1ab_2          16 KB  conda-forge
#     lazy_loader-0.4            |     pyhd8ed1ab_2           7 KB  conda-forge
#     lcms2-2.17                 |       h717163a_0         242 KB  conda-forge
#     ld_impl_linux-64-2.43      |       h712a8e2_4         656 KB  conda-forge
#     lerc-4.0.0                 |       h27087fc_0         275 KB  conda-forge
#     level-zero-1.21.8          |       h84d6215_0         539 KB  conda-forge
#     libabseil-20250127.1       | cxx17_hbbce691_0         1.3 MB  conda-forge
#     libasprintf-0.23.1         |       h8e693c7_0          42 KB  conda-forge
#     libasprintf-devel-0.23.1   |       h8e693c7_0          33 KB  conda-forge
#     libass-0.17.3              |       h52826cd_2         149 KB  conda-forge
#     libblas-3.9.0              |31_h59b9bed_openblas          16 KB  conda-forge
#     libbrotlicommon-1.1.0      |       hb9d3cd8_2          67 KB  conda-forge
#     libbrotlidec-1.1.0         |       hb9d3cd8_2          32 KB  conda-forge
#     libbrotlienc-1.1.0         |       hb9d3cd8_2         275 KB  conda-forge
#     libcap-2.75                |       h39aace5_0         118 KB  conda-forge
#     libcblas-3.9.0             |31_he106b2a_openblas          16 KB  conda-forge
#     libcups-2.3.3              |       h4637d8d_4         4.3 MB  conda-forge
#     libdb-6.2.32               |       h9c3ff4c_0        23.3 MB  conda-forge
#     libdeflate-1.23            |       h4ddbbb0_0          71 KB  conda-forge
#     libdrm-2.4.124             |       hb9d3cd8_0         237 KB  conda-forge
#     libedit-3.1.20250104       | pl5321h7949ede_0         132 KB  conda-forge
#     libegl-1.7.0               |       ha4b6fd6_2          44 KB  conda-forge
#     libexpat-2.7.0             |       h5888daf_0          73 KB  conda-forge
#     libffi-3.4.6               |       h2dba641_1          56 KB  conda-forge
#     libflac-1.4.3              |       h59595ed_0         385 KB  conda-forge
#     libgcc-14.2.0              |       h767d61c_2         828 KB  conda-forge
#     libgcc-ng-14.2.0           |       h69a702a_2          52 KB  conda-forge
#     libgcrypt-lib-1.11.0       |       hb9d3cd8_2         572 KB  conda-forge
#     libgd-2.3.3                |      h6f5c62b_11         173 KB  conda-forge
#     libgettextpo-0.23.1        |       h5888daf_0         163 KB  conda-forge
#     libgettextpo-devel-0.23.1  |       h5888daf_0          36 KB  conda-forge
#     libgfortran-14.2.0         |       h69a702a_2          52 KB  conda-forge
#     libgfortran5-14.2.0        |       hf1ad2bd_2         1.4 MB  conda-forge
#     libgl-1.7.0                |       ha4b6fd6_2         132 KB  conda-forge
#     libglib-2.84.1             |       h2ff4ddf_0         3.8 MB  conda-forge
#     libglvnd-1.7.0             |       ha4b6fd6_2         129 KB  conda-forge
#     libglx-1.7.0               |       ha4b6fd6_2          74 KB  conda-forge
#     libgomp-14.2.0             |       h767d61c_2         449 KB  conda-forge
#     libgpg-error-1.51          |       hbd13f7d_1         262 KB  conda-forge
#     libhwloc-2.11.2            |default_h0d58e46_1001         2.3 MB  conda-forge
#     libiconv-1.18              |       h4ce23a2_1         696 KB  conda-forge
#     libjpeg-turbo-3.0.0        |       hd590300_1         604 KB  conda-forge
#     liblapack-3.9.0            |31_h7ac8fdf_openblas          16 KB  conda-forge
#     liblapacke-3.9.0           |31_he2f377e_openblas          16 KB  conda-forge
#     liblzma-5.8.1              |       hb9d3cd8_0         110 KB  conda-forge
#     liblzma-devel-5.8.1        |       hb9d3cd8_0         431 KB  conda-forge
#     libnsl-2.0.1               |       hd590300_0          33 KB  conda-forge
#     libntlm-1.8                |       hb9d3cd8_0          33 KB  conda-forge
#     libogg-1.3.5               |       h4ab18f5_0         201 KB  conda-forge
#     libopenblas-0.3.29         |pthreads_h94d23a6_0         5.6 MB  conda-forge
#     libopenvino-2025.0.0       |       hdc3f47d_3         5.4 MB  conda-forge
#     libopenvino-auto-batch-plugin-2025.0.0|       h4d9b6c2_3         109 KB  conda-forge
#     libopenvino-auto-plugin-2025.0.0|       h4d9b6c2_3         233 KB  conda-forge
#     libopenvino-hetero-plugin-2025.0.0|       h981d57b_3         191 KB  conda-forge
#     libopenvino-intel-cpu-plugin-2025.0.0|       hdc3f47d_3        11.8 MB  conda-forge
#     libopenvino-intel-gpu-plugin-2025.0.0|       hdc3f47d_3         9.7 MB  conda-forge
#     libopenvino-intel-npu-plugin-2025.0.0|       hdc3f47d_3         1.0 MB  conda-forge
#     libopenvino-ir-frontend-2025.0.0|       h981d57b_3         201 KB  conda-forge
#     libopenvino-onnx-frontend-2025.0.0|       h0e684df_3         1.6 MB  conda-forge
#     libopenvino-paddle-frontend-2025.0.0|       h0e684df_3         674 KB  conda-forge
#     libopenvino-pytorch-frontend-2025.0.0|       h5888daf_3         1.1 MB  conda-forge
#     libopenvino-tensorflow-frontend-2025.0.0|       h684f15b_3         1.3 MB  conda-forge
#     libopenvino-tensorflow-lite-frontend-2025.0.0|       h5888daf_3         477 KB  conda-forge
#     libopus-1.3.1              |       h7f98852_1         255 KB  conda-forge
#     libpciaccess-0.18          |       hd590300_0          28 KB  conda-forge
#     libpng-1.6.47              |       h943b412_0         282 KB  conda-forge
#     libpq-17.4                 |       h27ae623_1         2.6 MB  conda-forge
#     libprotobuf-5.29.3         |       h501fc15_0         3.2 MB  conda-forge
#     librosa-0.11.0             |     pyhd8ed1ab_0         195 KB  conda-forge
#     librsvg-2.58.4             |       he92a37e_3         6.2 MB  conda-forge
#     libsndfile-1.2.2           |       hc60ed4a_1         346 KB  conda-forge
#     libsqlite-3.49.1           |       hee588c1_2         897 KB  conda-forge
#     libstdcxx-14.2.0           |       h8f9b012_2         3.7 MB  conda-forge
#     libstdcxx-ng-14.2.0        |       h4852527_2          53 KB  conda-forge
#     libsystemd0-257.4          |       h4e0b6ca_1         477 KB  conda-forge
#     libtiff-4.7.0              |       hd9ff511_3         418 KB  conda-forge
#     libudev1-257.4             |       hbe16f8c_1         141 KB  conda-forge
#     libunwind-1.6.2            |       h9c3ff4c_0          74 KB  conda-forge
#     liburing-2.9               |       h84d6215_0         118 KB  conda-forge
#     libusb-1.0.28              |       hb9d3cd8_0          86 KB  conda-forge
#     libuuid-2.38.1             |       h0b41bf4_0          33 KB  conda-forge
#     libva-2.22.0               |       h4f16b4b_2         212 KB  conda-forge
#     libvorbis-1.3.7            |       h9c3ff4c_0         280 KB  conda-forge
#     libvpx-1.14.1              |       hac33072_0         999 KB  conda-forge
#     libwebp-base-1.5.0         |       h851e524_0         420 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     libxcrypt-4.4.36           |       hd590300_1          98 KB  conda-forge
#     libxkbcommon-1.8.1         |       hc4a0caf_0         630 KB  conda-forge
#     libxml2-2.13.7             |       h4bc477f_1         676 KB  conda-forge
#     libxslt-1.1.39             |       h76b75d6_0         248 KB  conda-forge
#     libzlib-1.3.1              |       hb9d3cd8_2          60 KB  conda-forge
#     llvmlite-0.44.0            |  py311h9c9ff8c_1        28.6 MB  conda-forge
#     lz4-c-1.10.0               |       h5888daf_1         163 KB  conda-forge
#     mad-0.15.1b                |       h9c3ff4c_1         113 KB  conda-forge
#     markdown-it-py-3.0.0       |     pyhd8ed1ab_1          63 KB  conda-forge
#     matplotlib-base-3.10.1     |  py311h2b939e6_0         8.0 MB  conda-forge
#     mdurl-0.1.2                |     pyhd8ed1ab_1          14 KB  conda-forge
#     montreal-forced-aligner-3.2.1|     pyhd8ed1ab_0        11.0 MB  conda-forge
#     mpg123-1.32.9              |       hc50e24c_0         480 KB  conda-forge
#     msgpack-python-1.1.0       |  py311hd18a35c_0         102 KB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     ncurses-6.5                |       h2d0b736_3         871 KB  conda-forge
#     ngram-1.3.16               |       h434a139_1         2.0 MB  conda-forge
#     numba-0.61.0               |  py311h4e1c48f_1         5.7 MB  conda-forge
#     numpy-2.1.3                |  py311h71ddf71_0         8.6 MB  conda-forge
#     ocl-icd-2.3.3              |       hb9d3cd8_0         104 KB  conda-forge
#     opencl-headers-2024.10.24  |       h5888daf_0          53 KB  conda-forge
#     openfst-1.8.3              |       h84d6215_3         5.2 MB  conda-forge
#     openh264-2.6.0             |       hc22cd8d_0         714 KB  conda-forge
#     openjpeg-2.5.3             |       h5fbd93e_0         335 KB  conda-forge
#     openldap-2.6.9             |       he970967_0         766 KB  conda-forge
#     openssl-3.4.1              |       h7b32b05_0         2.8 MB  conda-forge
#     packaging-24.2             |     pyhd8ed1ab_2          59 KB  conda-forge
#     pango-1.56.3               |       h9ac818e_1         442 KB  conda-forge
#     pcre2-10.44                |       hba22ea6_2         930 KB  conda-forge
#     pgvector-0.8.0             |       hf59a245_1         116 KB  conda-forge
#     pgvector-python-0.4.0      |     pyhc48fcf7_0          23 KB  conda-forge
#     pillow-11.1.0              |  py311h1322bbf_0        40.1 MB  conda-forge
#     pip-25.0.1                 |     pyh8b19718_0         1.2 MB  conda-forge
#     pixman-0.44.2              |       h29eaf8c_0         372 KB  conda-forge
#     platformdirs-4.3.7         |     pyh29332c3_0          23 KB  conda-forge
#     pooch-1.8.2                |     pyhd8ed1ab_1          53 KB  conda-forge
#     postgresql-17.4            |       h9e3fa73_1         5.4 MB  conda-forge
#     praatio-6.0.0              |     pyhd8ed1ab_0          60 KB  conda-forge
#     psycopg2-2.9.9             |  py311h83e8966_2         186 KB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     pugixml-1.15               |       h3f63f65_0         116 KB  conda-forge
#     pulseaudio-client-17.0     |       hac146a9_1         746 KB  conda-forge
#     pycparser-2.22             |     pyh29332c3_1         108 KB  conda-forge
#     pygments-2.19.1            |     pyhd8ed1ab_0         868 KB  conda-forge
#     pynini-2.1.6               |  py311h9547e67_0         1.6 MB  conda-forge
#     pyparsing-3.2.3            |     pyhd8ed1ab_1          94 KB  conda-forge
#     pysocks-1.7.1              |     pyha55dd90_7          21 KB  conda-forge
#     pysoundfile-0.13.1         |     pyhd8ed1ab_0          30 KB  conda-forge
#     python-3.11.11             |h9e4cc4f_2_cpython        29.2 MB  conda-forge
#     python-dateutil-2.9.0.post0|     pyhff2d567_1         217 KB  conda-forge
#     python_abi-3.11            |          6_cp311           7 KB  conda-forge
#     pyyaml-6.0.2               |  py311h2dc5d0c_2         208 KB  conda-forge
#     qhull-2020.2               |       h434a139_5         540 KB  conda-forge
#     readline-8.2               |       h8c095d6_2         276 KB  conda-forge
#     requests-2.32.3            |     pyhd8ed1ab_1          57 KB  conda-forge
#     rich-14.0.0                |     pyh29332c3_0         196 KB  conda-forge
#     rich-click-1.8.8           |     pyhd8ed1ab_0          34 KB  conda-forge
#     scikit-learn-1.6.1         |  py311h57cc02b_0        10.2 MB  conda-forge
#     scipy-1.15.2               |  py311h8f841c2_0        16.4 MB  conda-forge
#     sdl2-2.32.54               |       h9b8e6db_0         515 KB  conda-forge
#     sdl3-3.2.10                |       h3083f51_0         1.7 MB  conda-forge
#     setuptools-78.1.0          |     pyhff2d567_0         768 KB  conda-forge
#     six-1.17.0                 |     pyhd8ed1ab_0          16 KB  conda-forge
#     snappy-1.2.1               |       h8bd8927_1          42 KB  conda-forge
#     sox-14.4.2                 |    h59a48fd_1020         496 KB  conda-forge
#     soxr-0.1.3                 |       h0b41bf4_3         128 KB  conda-forge
#     soxr-python-0.5.0.post1    |  py311hfdbb021_1          90 KB  conda-forge
#     sqlalchemy-2.0.40          |  py311h9ecbd09_0         3.4 MB  conda-forge
#     sqlite-3.49.1              |       h9eae976_2         839 KB  conda-forge
#     standard-aifc-3.13.0       |  py311h38be061_0          29 KB  conda-forge
#     standard-sunau-3.13.0      |  py311h38be061_0          21 KB  conda-forge
#     svt-av1-3.0.2              |       h5888daf_0         2.6 MB  conda-forge
#     tbb-2022.1.0               |       h4ce085d_0         175 KB  conda-forge
#     threadpoolctl-3.6.0        |     pyhecae5ae_0          23 KB  conda-forge
#     tk-8.6.13                  |noxft_h4845f30_101         3.2 MB  conda-forge
#     tqdm-4.67.1                |     pyhd8ed1ab_1          87 KB  conda-forge
#     typing-extensions-4.13.1   |       hf5ce1d7_0          88 KB  conda-forge
#     typing_extensions-4.13.1   |     pyh29332c3_0          51 KB  conda-forge
#     tzcode-2025b               |       hb9d3cd8_0          68 KB  conda-forge
#     tzdata-2025b               |       h78e105d_0         120 KB  conda-forge
#     unicodedata2-16.0.0        |  py311h9ecbd09_0         396 KB  conda-forge
#     urllib3-2.3.0              |     pyhd8ed1ab_0          98 KB  conda-forge
#     wayland-1.23.1             |       h3e06ad9_0         314 KB  conda-forge
#     wayland-protocols-1.42     |       hd8ed1ab_0         128 KB  conda-forge
#     wheel-0.45.1               |     pyhd8ed1ab_1          61 KB  conda-forge
#     x264-1!164.3095            |       h166bdaf_2         877 KB  conda-forge
#     x265-3.5                   |       h924138e_3         3.2 MB  conda-forge
#     xkeyboard-config-2.43      |       hb9d3cd8_0         380 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.6           |       he73a12e_0          27 KB  conda-forge
#     xorg-libx11-1.8.12         |       h4f16b4b_0         816 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxcomposite-0.4.6   |       hb9d3cd8_2          13 KB  conda-forge
#     xorg-libxcursor-1.2.3      |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxdamage-1.1.6      |       hb9d3cd8_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxext-1.3.6         |       hb9d3cd8_0          49 KB  conda-forge
#     xorg-libxfixes-6.0.1       |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxi-1.8.2           |       hb9d3cd8_0          46 KB  conda-forge
#     xorg-libxinerama-1.1.5     |       h5888daf_1          14 KB  conda-forge
#     xorg-libxrandr-1.5.4       |       hb9d3cd8_0          29 KB  conda-forge
#     xorg-libxrender-0.9.12     |       hb9d3cd8_0          32 KB  conda-forge
#     xorg-libxscrnsaver-1.2.4   |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxtst-1.2.5         |       hb9d3cd8_3          32 KB  conda-forge
#     yaml-0.2.5                 |       h7f98852_2          87 KB  conda-forge
#     zipp-3.21.0                |     pyhd8ed1ab_1          21 KB  conda-forge
#     zlib-1.3.1                 |       hb9d3cd8_2          90 KB  conda-forge
#     zstandard-0.23.0           |  py311h9ecbd09_1         715 KB  conda-forge
#     zstd-1.5.7                 |       hb8e6e7a_2         554 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       398.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   adwaita-icon-theme conda-forge/noarch::adwaita-icon-theme-48.0-unix_0
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.13-hb9d3cd8_0
#   aom                conda-forge/linux-64::aom-3.9.1-hac33072_0
#   at-spi2-atk        conda-forge/linux-64::at-spi2-atk-2.38.0-h0630a04_3
#   at-spi2-core       conda-forge/linux-64::at-spi2-core-2.40.3-h0630a04_0
#   atk-1.0            conda-forge/linux-64::atk-1.0-2.38.0-h04ea711_2
#   attr               conda-forge/linux-64::attr-2.5.1-h166bdaf_1
#   audioread          conda-forge/linux-64::audioread-3.0.1-py311h38be061_2
#   baumwelch          conda-forge/linux-64::baumwelch-0.3.9-h434a139_3
#   biopython          conda-forge/linux-64::biopython-1.79-py311hd4cff14_3
#   brotli             conda-forge/linux-64::brotli-1.1.0-hb9d3cd8_2
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.1.0-hb9d3cd8_2
#   brotli-python      conda-forge/linux-64::brotli-python-1.1.0-py311hfdbb021_2
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h4bc722e_7
#   ca-certificates    conda-forge/linux-64::ca-certificates-2025.1.31-hbcca054_0
#   cairo              conda-forge/linux-64::cairo-1.18.4-h3394656_0
#   certifi            conda-forge/noarch::certifi-2025.1.31-pyhd8ed1ab_0
#   cffi               conda-forge/linux-64::cffi-1.17.1-py311hf29c0ef_0
#   charset-normalizer conda-forge/noarch::charset-normalizer-3.4.1-pyhd8ed1ab_0
#   click              conda-forge/noarch::click-8.1.8-pyh707e725_0
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_1
#   contourpy          conda-forge/linux-64::contourpy-1.3.1-py311hd18a35c_0
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_1
#   cyrus-sasl         conda-forge/linux-64::cyrus-sasl-2.1.27-h54b06d7_7
#   dataclassy         conda-forge/noarch::dataclassy-1.0.1-pyhd8ed1ab_0
#   dav1d              conda-forge/linux-64::dav1d-1.2.1-hd590300_0
#   dbus               conda-forge/linux-64::dbus-1.13.6-h5008d03_3
#   decorator          conda-forge/noarch::decorator-5.2.1-pyhd8ed1ab_0
#   epoxy              conda-forge/linux-64::epoxy-1.5.10-h166bdaf_1
#   expat              conda-forge/linux-64::expat-2.7.0-h5888daf_0
#   ffmpeg             conda-forge/linux-64::ffmpeg-7.1.1-gpl_h0b79d52_704
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.15.0-h7e30c49_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fonttools          conda-forge/linux-64::fonttools-4.57.0-py311h2dc5d0c_0
#   freetype           conda-forge/linux-64::freetype-2.13.3-h48d6fc4_0
#   fribidi            conda-forge/linux-64::fribidi-1.0.10-h36c2ea0_0
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.12-hb9ae30d_0
#   gettext            conda-forge/linux-64::gettext-0.23.1-h5888daf_0
#   gettext-tools      conda-forge/linux-64::gettext-tools-0.23.1-h5888daf_0
#   glib-tools         conda-forge/linux-64::glib-tools-2.84.1-h4833e2c_0
#   gmp                conda-forge/linux-64::gmp-6.3.0-hac33072_2
#   graphite2          conda-forge/linux-64::graphite2-1.3.13-h59595ed_1003
#   graphviz           conda-forge/linux-64::graphviz-12.2.1-h5ae0cbf_1
#   greenlet           conda-forge/linux-64::greenlet-3.1.1-py311hfdbb021_1
#   gtk3               conda-forge/linux-64::gtk3-3.24.43-h0c6a113_5
#   gts                conda-forge/linux-64::gts-0.7.6-h977cf35_4
#   h2                 conda-forge/noarch::h2-4.2.0-pyhd8ed1ab_0
#   harfbuzz           conda-forge/linux-64::harfbuzz-11.0.1-h2c12942_0
#   hdbscan            conda-forge/linux-64::hdbscan-0.8.39-py311h9f3472d_0
#   hicolor-icon-theme conda-forge/linux-64::hicolor-icon-theme-0.17-ha770c72_2
#   hpack              conda-forge/noarch::hpack-4.1.0-pyhd8ed1ab_0
#   hyperframe         conda-forge/noarch::hyperframe-6.1.0-pyhd8ed1ab_0
#   icu                conda-forge/linux-64::icu-75.1-he02047a_0
#   idna               conda-forge/noarch::idna-3.10-pyhd8ed1ab_1
#   importlib-metadata conda-forge/noarch::importlib-metadata-8.6.1-pyha770c72_0
#   jack               conda-forge/linux-64::jack-1.9.22-h7c63dc7_2
#   joblib             conda-forge/noarch::joblib-1.4.2-pyhd8ed1ab_1
#   kaldi              conda-forge/linux-64::kaldi-5.5.1112-cpu_hb028f0a_7
#   kalpy              conda-forge/linux-64::kalpy-0.6.9-py311hd18a35c_0
#   keyutils           conda-forge/linux-64::keyutils-1.6.1-h166bdaf_0
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.4.7-py311hd18a35c_0
#   kneed              conda-forge/noarch::kneed-0.8.5-pyhd8ed1ab_1
#   krb5               conda-forge/linux-64::krb5-1.21.3-h659f571_0
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   lazy-loader        conda-forge/noarch::lazy-loader-0.4-pyhd8ed1ab_2
#   lazy_loader        conda-forge/noarch::lazy_loader-0.4-pyhd8ed1ab_2
#   lcms2              conda-forge/linux-64::lcms2-2.17-h717163a_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.43-h712a8e2_4
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   level-zero         conda-forge/linux-64::level-zero-1.21.8-h84d6215_0
#   libabseil          conda-forge/linux-64::libabseil-20250127.1-cxx17_hbbce691_0
#   libasprintf        conda-forge/linux-64::libasprintf-0.23.1-h8e693c7_0
#   libasprintf-devel  conda-forge/linux-64::libasprintf-devel-0.23.1-h8e693c7_0
#   libass             conda-forge/linux-64::libass-0.17.3-h52826cd_2
#   libblas            conda-forge/linux-64::libblas-3.9.0-31_h59b9bed_openblas
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.1.0-hb9d3cd8_2
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.1.0-hb9d3cd8_2
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.1.0-hb9d3cd8_2
#   libcap             conda-forge/linux-64::libcap-2.75-h39aace5_0
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-31_he106b2a_openblas
#   libcups            conda-forge/linux-64::libcups-2.3.3-h4637d8d_4
#   libdb              conda-forge/linux-64::libdb-6.2.32-h9c3ff4c_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.23-h4ddbbb0_0
#   libdrm             conda-forge/linux-64::libdrm-2.4.124-hb9d3cd8_0
#   libedit            conda-forge/linux-64::libedit-3.1.20250104-pl5321h7949ede_0
#   libegl             conda-forge/linux-64::libegl-1.7.0-ha4b6fd6_2
#   libexpat           conda-forge/linux-64::libexpat-2.7.0-h5888daf_0
#   libffi             conda-forge/linux-64::libffi-3.4.6-h2dba641_1
#   libflac            conda-forge/linux-64::libflac-1.4.3-h59595ed_0
#   libgcc             conda-forge/linux-64::libgcc-14.2.0-h767d61c_2
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-14.2.0-h69a702a_2
#   libgcrypt-lib      conda-forge/linux-64::libgcrypt-lib-1.11.0-hb9d3cd8_2
#   libgd              conda-forge/linux-64::libgd-2.3.3-h6f5c62b_11
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.23.1-h5888daf_0
#   libgettextpo-devel conda-forge/linux-64::libgettextpo-devel-0.23.1-h5888daf_0
#   libgfortran        conda-forge/linux-64::libgfortran-14.2.0-h69a702a_2
#   libgfortran5       conda-forge/linux-64::libgfortran5-14.2.0-hf1ad2bd_2
#   libgl              conda-forge/linux-64::libgl-1.7.0-ha4b6fd6_2
#   libglib            conda-forge/linux-64::libglib-2.84.1-h2ff4ddf_0
#   libglvnd           conda-forge/linux-64::libglvnd-1.7.0-ha4b6fd6_2
#   libglx             conda-forge/linux-64::libglx-1.7.0-ha4b6fd6_2
#   libgomp            conda-forge/linux-64::libgomp-14.2.0-h767d61c_2
#   libgpg-error       conda-forge/linux-64::libgpg-error-1.51-hbd13f7d_1
#   libhwloc           conda-forge/linux-64::libhwloc-2.11.2-default_h0d58e46_1001
#   libiconv           conda-forge/linux-64::libiconv-1.18-h4ce23a2_1
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.0.0-hd590300_1
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-31_h7ac8fdf_openblas
#   liblapacke         conda-forge/linux-64::liblapacke-3.9.0-31_he2f377e_openblas
#   liblzma            conda-forge/linux-64::liblzma-5.8.1-hb9d3cd8_0
#   liblzma-devel      conda-forge/linux-64::liblzma-devel-5.8.1-hb9d3cd8_0
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
#   libntlm            conda-forge/linux-64::libntlm-1.8-hb9d3cd8_0
#   libogg             conda-forge/linux-64::libogg-1.3.5-h4ab18f5_0
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.29-pthreads_h94d23a6_0
#   libopenvino        conda-forge/linux-64::libopenvino-2025.0.0-hdc3f47d_3
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-batch-plugin-2025.0.0-h4d9b6c2_3
#   libopenvino-auto-~ conda-forge/linux-64::libopenvino-auto-plugin-2025.0.0-h4d9b6c2_3
#   libopenvino-heter~ conda-forge/linux-64::libopenvino-hetero-plugin-2025.0.0-h981d57b_3
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-cpu-plugin-2025.0.0-hdc3f47d_3
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-gpu-plugin-2025.0.0-hdc3f47d_3
#   libopenvino-intel~ conda-forge/linux-64::libopenvino-intel-npu-plugin-2025.0.0-hdc3f47d_3
#   libopenvino-ir-fr~ conda-forge/linux-64::libopenvino-ir-frontend-2025.0.0-h981d57b_3
#   libopenvino-onnx-~ conda-forge/linux-64::libopenvino-onnx-frontend-2025.0.0-h0e684df_3
#   libopenvino-paddl~ conda-forge/linux-64::libopenvino-paddle-frontend-2025.0.0-h0e684df_3
#   libopenvino-pytor~ conda-forge/linux-64::libopenvino-pytorch-frontend-2025.0.0-h5888daf_3
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-frontend-2025.0.0-h684f15b_3
#   libopenvino-tenso~ conda-forge/linux-64::libopenvino-tensorflow-lite-frontend-2025.0.0-h5888daf_3
#   libopus            conda-forge/linux-64::libopus-1.3.1-h7f98852_1
#   libpciaccess       conda-forge/linux-64::libpciaccess-0.18-hd590300_0
#   libpng             conda-forge/linux-64::libpng-1.6.47-h943b412_0
#   libpq              conda-forge/linux-64::libpq-17.4-h27ae623_1
#   libprotobuf        conda-forge/linux-64::libprotobuf-5.29.3-h501fc15_0
#   librosa            conda-forge/noarch::librosa-0.11.0-pyhd8ed1ab_0
#   librsvg            conda-forge/linux-64::librsvg-2.58.4-he92a37e_3
#   libsndfile         conda-forge/linux-64::libsndfile-1.2.2-hc60ed4a_1
#   libsqlite          conda-forge/linux-64::libsqlite-3.49.1-hee588c1_2
#   libstdcxx          conda-forge/linux-64::libstdcxx-14.2.0-h8f9b012_2
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-14.2.0-h4852527_2
#   libsystemd0        conda-forge/linux-64::libsystemd0-257.4-h4e0b6ca_1
#   libtiff            conda-forge/linux-64::libtiff-4.7.0-hd9ff511_3
#   libudev1           conda-forge/linux-64::libudev1-257.4-hbe16f8c_1
#   libunwind          conda-forge/linux-64::libunwind-1.6.2-h9c3ff4c_0
#   liburing           conda-forge/linux-64::liburing-2.9-h84d6215_0
#   libusb             conda-forge/linux-64::libusb-1.0.28-hb9d3cd8_0
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libva              conda-forge/linux-64::libva-2.22.0-h4f16b4b_2
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h9c3ff4c_0
#   libvpx             conda-forge/linux-64::libvpx-1.14.1-hac33072_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.5.0-h851e524_0
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.8.1-hc4a0caf_0
#   libxml2            conda-forge/linux-64::libxml2-2.13.7-h4bc477f_1
#   libxslt            conda-forge/linux-64::libxslt-1.1.39-h76b75d6_0
#   libzlib            conda-forge/linux-64::libzlib-1.3.1-hb9d3cd8_2
#   llvmlite           conda-forge/linux-64::llvmlite-0.44.0-py311h9c9ff8c_1
#   lz4-c              conda-forge/linux-64::lz4-c-1.10.0-h5888daf_1
#   mad                conda-forge/linux-64::mad-0.15.1b-h9c3ff4c_1
#   markdown-it-py     conda-forge/noarch::markdown-it-py-3.0.0-pyhd8ed1ab_1
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.10.1-py311h2b939e6_0
#   mdurl              conda-forge/noarch::mdurl-0.1.2-pyhd8ed1ab_1
#   montreal-forced-a~ conda-forge/noarch::montreal-forced-aligner-3.2.1-pyhd8ed1ab_0
#   mpg123             conda-forge/linux-64::mpg123-1.32.9-hc50e24c_0
#   msgpack-python     conda-forge/linux-64::msgpack-python-1.1.0-py311hd18a35c_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   ncurses            conda-forge/linux-64::ncurses-6.5-h2d0b736_3
#   ngram              conda-forge/linux-64::ngram-1.3.16-h434a139_1
#   numba              conda-forge/linux-64::numba-0.61.0-py311h4e1c48f_1
#   numpy              conda-forge/linux-64::numpy-2.1.3-py311h71ddf71_0
#   ocl-icd            conda-forge/linux-64::ocl-icd-2.3.3-hb9d3cd8_0
#   opencl-headers     conda-forge/linux-64::opencl-headers-2024.10.24-h5888daf_0
#   openfst            conda-forge/linux-64::openfst-1.8.3-h84d6215_3
#   openh264           conda-forge/linux-64::openh264-2.6.0-hc22cd8d_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.3-h5fbd93e_0
#   openldap           conda-forge/linux-64::openldap-2.6.9-he970967_0
#   openssl            conda-forge/linux-64::openssl-3.4.1-h7b32b05_0
#   packaging          conda-forge/noarch::packaging-24.2-pyhd8ed1ab_2
#   pango              conda-forge/linux-64::pango-1.56.3-h9ac818e_1
#   pcre2              conda-forge/linux-64::pcre2-10.44-hba22ea6_2
#   pgvector           conda-forge/linux-64::pgvector-0.8.0-hf59a245_1
#   pgvector-python    conda-forge/noarch::pgvector-python-0.4.0-pyhc48fcf7_0
#   pillow             conda-forge/linux-64::pillow-11.1.0-py311h1322bbf_0
#   pip                conda-forge/noarch::pip-25.0.1-pyh8b19718_0
#   pixman             conda-forge/linux-64::pixman-0.44.2-h29eaf8c_0
#   platformdirs       conda-forge/noarch::platformdirs-4.3.7-pyh29332c3_0
#   pooch              conda-forge/noarch::pooch-1.8.2-pyhd8ed1ab_1
#   postgresql         conda-forge/linux-64::postgresql-17.4-h9e3fa73_1
#   praatio            conda-forge/noarch::praatio-6.0.0-pyhd8ed1ab_0
#   psycopg2           conda-forge/linux-64::psycopg2-2.9.9-py311h83e8966_2
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   pugixml            conda-forge/linux-64::pugixml-1.15-h3f63f65_0
#   pulseaudio-client  conda-forge/linux-64::pulseaudio-client-17.0-hac146a9_1
#   pycparser          conda-forge/noarch::pycparser-2.22-pyh29332c3_1
#   pygments           conda-forge/noarch::pygments-2.19.1-pyhd8ed1ab_0
#   pynini             conda-forge/linux-64::pynini-2.1.6-py311h9547e67_0
#   pyparsing          conda-forge/noarch::pyparsing-3.2.3-pyhd8ed1ab_1
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyha55dd90_7
#   pysoundfile        conda-forge/noarch::pysoundfile-0.13.1-pyhd8ed1ab_0
#   python             conda-forge/linux-64::python-3.11.11-h9e4cc4f_2_cpython
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0.post0-pyhff2d567_1
#   python_abi         conda-forge/linux-64::python_abi-3.11-6_cp311
#   pyyaml             conda-forge/linux-64::pyyaml-6.0.2-py311h2dc5d0c_2
#   qhull              conda-forge/linux-64::qhull-2020.2-h434a139_5
#   readline           conda-forge/linux-64::readline-8.2-h8c095d6_2
#   requests           conda-forge/noarch::requests-2.32.3-pyhd8ed1ab_1
#   rich               conda-forge/noarch::rich-14.0.0-pyh29332c3_0
#   rich-click         conda-forge/noarch::rich-click-1.8.8-pyhd8ed1ab_0
#   scikit-learn       conda-forge/linux-64::scikit-learn-1.6.1-py311h57cc02b_0
#   scipy              conda-forge/linux-64::scipy-1.15.2-py311h8f841c2_0
#   sdl2               conda-forge/linux-64::sdl2-2.32.54-h9b8e6db_0
#   sdl3               conda-forge/linux-64::sdl3-3.2.10-h3083f51_0
#   setuptools         conda-forge/noarch::setuptools-78.1.0-pyhff2d567_0
#   six                conda-forge/noarch::six-1.17.0-pyhd8ed1ab_0
#   snappy             conda-forge/linux-64::snappy-1.2.1-h8bd8927_1
#   sox                conda-forge/linux-64::sox-14.4.2-h59a48fd_1020
#   soxr               conda-forge/linux-64::soxr-0.1.3-h0b41bf4_3
#   soxr-python        conda-forge/linux-64::soxr-python-0.5.0.post1-py311hfdbb021_1
#   sqlalchemy         conda-forge/linux-64::sqlalchemy-2.0.40-py311h9ecbd09_0
#   sqlite             conda-forge/linux-64::sqlite-3.49.1-h9eae976_2
#   standard-aifc      conda-forge/linux-64::standard-aifc-3.13.0-py311h38be061_0
#   standard-sunau     conda-forge/linux-64::standard-sunau-3.13.0-py311h38be061_0
#   svt-av1            conda-forge/linux-64::svt-av1-3.0.2-h5888daf_0
#   tbb                conda-forge/linux-64::tbb-2022.1.0-h4ce085d_0
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.6.0-pyhecae5ae_0
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_h4845f30_101
#   tqdm               conda-forge/noarch::tqdm-4.67.1-pyhd8ed1ab_1
#   typing-extensions  conda-forge/noarch::typing-extensions-4.13.1-hf5ce1d7_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.13.1-pyh29332c3_0
#   tzcode             conda-forge/linux-64::tzcode-2025b-hb9d3cd8_0
#   tzdata             conda-forge/noarch::tzdata-2025b-h78e105d_0
#   unicodedata2       conda-forge/linux-64::unicodedata2-16.0.0-py311h9ecbd09_0
#   urllib3            conda-forge/noarch::urllib3-2.3.0-pyhd8ed1ab_0
#   wayland            conda-forge/linux-64::wayland-1.23.1-h3e06ad9_0
#   wayland-protocols  conda-forge/noarch::wayland-protocols-1.42-hd8ed1ab_0
#   wheel              conda-forge/noarch::wheel-0.45.1-pyhd8ed1ab_1
#   x264               conda-forge/linux-64::x264-1!164.3095-h166bdaf_2
#   x265               conda-forge/linux-64::x265-3.5-h924138e_3
#   xkeyboard-config   conda-forge/linux-64::xkeyboard-config-2.43-hb9d3cd8_0
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.6-he73a12e_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.12-h4f16b4b_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb9d3cd8_0
#   xorg-libxcomposite conda-forge/linux-64::xorg-libxcomposite-0.4.6-hb9d3cd8_2
#   xorg-libxcursor    conda-forge/linux-64::xorg-libxcursor-1.2.3-hb9d3cd8_0
#   xorg-libxdamage    conda-forge/linux-64::xorg-libxdamage-1.1.6-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.6-hb9d3cd8_0
#   xorg-libxfixes     conda-forge/linux-64::xorg-libxfixes-6.0.1-hb9d3cd8_0
#   xorg-libxi         conda-forge/linux-64::xorg-libxi-1.8.2-hb9d3cd8_0
#   xorg-libxinerama   conda-forge/linux-64::xorg-libxinerama-1.1.5-h5888daf_1
#   xorg-libxrandr     conda-forge/linux-64::xorg-libxrandr-1.5.4-hb9d3cd8_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.12-hb9d3cd8_0
#   xorg-libxscrnsaver conda-forge/linux-64::xorg-libxscrnsaver-1.2.4-hb9d3cd8_0
#   xorg-libxtst       conda-forge/linux-64::xorg-libxtst-1.2.5-hb9d3cd8_3
#   yaml               conda-forge/linux-64::yaml-0.2.5-h7f98852_2
#   zipp               conda-forge/noarch::zipp-3.21.0-pyhd8ed1ab_1
#   zlib               conda-forge/linux-64::zlib-1.3.1-hb9d3cd8_2
#   zstandard          conda-forge/linux-64::zstandard-0.23.0-py311h9ecbd09_1
#   zstd               conda-forge/linux-64::zstd-1.5.7-hb8e6e7a_2
#
#
#
# Downloading and Extracting Packages:
# pillow-11.1.0        | 40.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
# python-3.11.11       | 29.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# llvmlite-0.44.0      | 28.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libdb-6.2.32         | 23.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# kaldi-5.5.1112       | 20.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# scipy-1.15.2         | 16.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# montreal-forced-alig | 11.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# scikit-learn-1.6.1   | 10.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# ffmpeg-7.1.1         | 9.9 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 9.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.1.3          | 8.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.4       | 6.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.61.0         | 5.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2025.0.0 | 5.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# postgresql-17.4      | 5.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# pillow-11.1.0        | 40.1 MB   | :   0% 0.0007797835034667621/1 [00:00<02:12, 132.80s/it]
#
#
# libdb-6.2.32         | 23.3 MB   | :   0% 0.0013424305728075218/1 [00:00<01:17, 77.24s/it]
#
#
#
# kaldi-5.5.1112       | 20.3 MB   | :   0% 0.0007714118824361511/1 [00:00<02:13, 133.19s/it]
# pillow-11.1.0        | 40.1 MB   | :   8% 0.07992780910534311/1 [00:00<00:02,  2.20s/it]
#
# llvmlite-0.44.0      | 28.6 MB   | :   8% 0.08293203268944072/1 [00:00<00:01,  2.16s/it]
#
#
# libdb-6.2.32         | 23.3 MB   | :  12% 0.12484604327109952/1 [00:00<00:01,  1.43s/it]
#
#
#
# kaldi-5.5.1112       | 20.3 MB   | :  16% 0.15891084778184714/1 [00:00<00:00,  1.10s/it]
# pillow-11.1.0        | 40.1 MB   | :  19% 0.18597836557682276/1 [00:00<00:01,  1.38s/it]
#
# llvmlite-0.44.0      | 28.6 MB   | :  21% 0.21005810911470182/1 [00:00<00:00,  1.22s/it]
#
#
#
# kaldi-5.5.1112       | 20.3 MB   | :  38% 0.3833917055707671/1 [00:00<00:00,  1.51it/s]
#
#
# libdb-6.2.32         | 23.3 MB   | :  28% 0.275198267425542/1 [00:00<00:00,  1.05it/s]
# pillow-11.1.0        | 40.1 MB   | :  28% 0.2822816282549679/1 [00:00<00:00,  1.22s/it]
#
# llvmlite-0.44.0      | 28.6 MB   | :  37% 0.3748309635371433/1 [00:00<00:00,  1.14it/s]
#
#
#
# kaldi-5.5.1112       | 20.3 MB   | :  54% 0.5369026701755611/1 [00:00<00:00,  1.52it/s]
#
#
# libdb-6.2.32         | 23.3 MB   | :  48% 0.4752204227738627/1 [00:00<00:00,  1.41it/s]
# pillow-11.1.0        | 40.1 MB   | :  39% 0.38794229297471416/1 [00:00<00:00,  1.11s/it]
#
# llvmlite-0.44.0      | 28.6 MB   | :  51% 0.5068674892663844/1 [00:00<00:00,  1.20it/s]
#
#
#
# kaldi-5.5.1112       | 20.3 MB   | :  72% 0.7235843457251098/1 [00:00<00:00,  1.63it/s]
#
#
# libdb-6.2.32         | 23.3 MB   | :  66% 0.6631607029669158/1 [00:00<00:00,  1.57it/s]
# python-3.11.11       | 29.2 MB   | :  60% 0.6003213203571413/1 [00:00<00:00,  1.39it/s]
#
#
#
# pillow-11.1.0        | 40.1 MB   | :  51% 0.5084188442603289/1 [00:00<00:00,  1.04s/it]
#
# llvmlite-0.44.0      | 28.6 MB   | :  63% 0.6345391711698656/1 [00:00<00:00,  1.17it/s]
#
#
# libdb-6.2.32         | 23.3 MB   | :  82% 0.8208962952717996/1 [00:00<00:00,  1.51it/s]
# pillow-11.1.0        | 40.1 MB   | :  61% 0.6082311327040745/1 [00:00<00:00,  1.05s/it]
#
# llvmlite-0.44.0      | 28.6 MB   | :  76% 0.7616652475951267/1 [00:00<00:00,  1.19it/s]
#
#
# libdb-6.2.32         | 23.3 MB   | : 100% 1.0/1 [00:00<00:00,  1.58it/s]
# pillow-11.1.0        | 40.1 MB   | :  72% 0.7154513644307542/1 [00:00<00:00,  1.02s/it]
#
# llvmlite-0.44.0      | 28.6 MB   | :  97% 0.9651760909711884/1 [00:00<00:00,  1.42it/s]
#
#
#
# pillow-11.1.0        | 40.1 MB   | :  83% 0.8331986734542353/1 [00:00<00:00,  1.04it/s]
#
#
#
#
# pillow-11.1.0        | 40.1 MB   | :  95% 0.9458773897051824/1 [00:01<00:00,  1.06it/s]
#
#
#
#
# scipy-1.15.2         | 16.4 MB   | :  20% 0.20392894229938174/1 [00:01<00:03,  3.79s/it]
#
#
# libdb-6.2.32         | 23.3 MB   | : 100% 1.0/1 [00:01<00:00,  1.58it/s]
#
#
#
#
# scipy-1.15.2         | 16.4 MB   | :  47% 0.4707518574574513/1 [00:01<00:00,  1.56s/it]
#
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | :   0% 0.001319237418932603/1 [00:01<14:43, 884.30s/it]
#
#
#
#
# scipy-1.15.2         | 16.4 MB   | :  68% 0.6803984336530774/1 [00:01<00:00,  1.12s/it]
#
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | :  32% 0.3205746928006225/1 [00:01<00:01,  2.87s/it]
#
#
#
#
# scipy-1.15.2         | 16.4 MB   | :  88% 0.8786097420562148/1 [00:01<00:00,  1.11it/s]
#
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | :  61% 0.6121261623847277/1 [00:01<00:00,  1.46s/it]
#
# llvmlite-0.44.0      | 28.6 MB   | : 100% 1.0/1 [00:01<00:00,  1.42it/s]
#
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | :  93% 0.9327008551853503/1 [00:01<00:00,  1.08it/s]
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :   0% 0.00135078949540213/1 [00:01<18:27, 1108.78s/it]
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :  29% 0.28501658352984943/1 [00:01<00:02,  4.04s/it]
# python-3.11.11       | 29.2 MB   | : 100% 1.0/1 [00:01<00:00,  1.26it/s]
#
#
#
#
#
#
#
# montreal-forced-alig | 11.0 MB   | :   0% 0.0014176480920502165/1 [00:01<19:47, 1189.04s/it]
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :  45% 0.4525144809597135/1 [00:01<00:01,  2.48s/it]
#
#
#
#
#
#
#
# montreal-forced-alig | 11.0 MB   | :  22% 0.21831780617573332/1 [00:01<00:04,  5.89s/it]
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :  61% 0.6146092204079691/1 [00:01<00:00,  1.76s/it]
#
#
#
#
#
#
#
# montreal-forced-alig | 11.0 MB   | :  38% 0.38418263294560867/1 [00:01<00:01,  3.16s/it]
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :  78% 0.7767039598562246/1 [00:01<00:00,  1.40s/it]
#
#
#
#
#
#
#
# montreal-forced-alig | 11.0 MB   | :  75% 0.7499358406945645/1 [00:02<00:00,  1.36s/it]
#
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | : 100% 1.0/1 [00:02<00:00,  1.08it/s]
#
#
#
#
#
#
#
#
# scikit-learn-1.6.1   | 10.2 MB   | :   0% 0.0015245176191396935/1 [00:02<23:03, 1385.83s/it]
#
#
#
#
# scipy-1.15.2         | 16.4 MB   | : 100% 1.0/1 [00:02<00:00,  1.11it/s]
#
#
#
#
#
#
#
#
# scikit-learn-1.6.1   | 10.2 MB   | :  37% 0.3689332638318058/1 [00:02<00:02,  4.30s/it]
#
#
#
#
#
#
#
#
#
# ffmpeg-7.1.1         | 9.9 MB    | :   0% 0.0015790239619584755/1 [00:02<23:27, 1409.25s/it]
#
#
#
#
#
#
#
#
#
# ffmpeg-7.1.1         | 9.9 MB    | :  35% 0.3505433195547816/1 [00:02<00:03,  4.76s/it]
#
#
#
#
#
#
#
#
# scikit-learn-1.6.1   | 10.2 MB   | :  71% 0.7104252105190971/1 [00:02<00:00,  2.05s/it]
#
#
#
#
#
#
#
#
#
# ffmpeg-7.1.1         | 9.9 MB    | :  56% 0.5589744825333003/1 [00:02<00:01,  2.80s/it]
#
#
#
#
#
#
#
#
# scikit-learn-1.6.1   | 10.2 MB   | : 100% 1.0/1 [00:02<00:00,  1.37s/it]
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:02<00:00,  1.91s/it]
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:02<00:00,  1.91s/it]
#
#
#
#
#
#
#
#
#
# ffmpeg-7.1.1         | 9.9 MB    | :  75% 0.7531944298541928/1 [00:02<00:00,  1.99s/it]
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 9.7 MB    | :   0% 0.0016190475249344585/1 [00:02<26:49, 1611.62s/it]
#
#
#
#
#
#
#
# montreal-forced-alig | 11.0 MB   | : 100% 1.0/1 [00:02<00:00,  1.83s/it]
#
#
#
#
#
#
#
# montreal-forced-alig | 11.0 MB   | : 100% 1.0/1 [00:02<00:00,  1.83s/it]
#
#
#
#
#
#
#
#
#
# ffmpeg-7.1.1         | 9.9 MB    | :  95% 0.9537304730229191/1 [00:02<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.1.3          | 8.6 MB    | :   0% 0.0018248823555684808/1 [00:02<24:42, 1484.71s/it]
#
#
#
#
#
#
#
#
#
#
# pillow-11.1.0        | 40.1 MB   | : 100% 1.0/1 [00:02<00:00,  1.06it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.0 MB    | :   0% 0.0019426210634474932/1 [00:02<23:59, 1442.33s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.1.3          | 8.6 MB    | :  34% 0.3449027652024429/1 [00:02<00:03,  5.81s/it]
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 9.7 MB    | :  57% 0.5682856812519949/1 [00:02<00:01,  3.00s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.0 MB    | :  35% 0.3535570335474438/1 [00:02<00:03,  5.87s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.1.3          | 8.6 MB    | :  70% 0.6952801774715912/1 [00:02<00:00,  2.54s/it]
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 9.7 MB    | :  88% 0.8807618535643453/1 [00:02<00:00,  1.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.0 MB    | :  75% 0.7517943515541798/1 [00:03<00:00,  2.41s/it]
#
#
#
#
#
#
#
#
# scikit-learn-1.6.1   | 10.2 MB   | : 100% 1.0/1 [00:03<00:00,  1.37s/it]
#
#
#
#
#
#
#
#
#
# ffmpeg-7.1.1         | 9.9 MB    | : 100% 1.0/1 [00:03<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.4       | 6.2 MB    | :   0% 0.002503801012615129/1 [00:03<20:25, 1228.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.61.0         | 5.7 MB    | :   0% 0.002741314847305216/1 [00:03<18:49, 1132.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.4       | 6.2 MB    | :  65% 0.6509882632799335/1 [00:03<00:01,  3.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.61.0         | 5.7 MB    | :  65% 0.646950303964031/1 [00:03<00:01,  3.53s/it]
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 9.7 MB    | : 100% 1.0/1 [00:03<00:00,  1.72s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.1.3          | 8.6 MB    | : 100% 1.0/1 [00:03<00:00,  2.05s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.1.3          | 8.6 MB    | : 100% 1.0/1 [00:03<00:00,  2.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :   0% 0.0027679004637044184/1 [00:03<20:19, 1222.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2025.0.0 | 5.4 MB    | :   0% 0.002875059334072103/1 [00:03<19:39, 1183.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.0 MB    | : 100% 1.0/1 [00:03<00:00,  2.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :  32% 0.32107645378971256/1 [00:03<00:05,  7.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2025.0.0 | 5.4 MB    | :  43% 0.4312589001108154/1 [00:03<00:03,  5.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# postgresql-17.4      | 5.4 MB    | :   0% 0.0029164130113601976/1 [00:03<20:04, 1208.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.4       | 6.2 MB    | : 100% 1.0/1 [00:03<00:00,  3.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.61.0         | 5.7 MB    | : 100% 1.0/1 [00:03<00:00,  3.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | :  82% 0.8165306367928035/1 [00:03<00:00,  2.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2025.0.0 | 5.4 MB    | :  86% 0.8596427408875588/1 [00:03<00:00,  2.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# postgresql-17.4      | 5.4 MB    | :  55% 0.5512020591470773/1 [00:03<00:02,  4.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2025.0.0 | 5.4 MB    | : 100% 1.0/1 [00:03<00:00,  2.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | : 100% 1.0/1 [00:03<00:00,  2.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# postgresql-17.4      | 5.4 MB    | : 100% 1.0/1 [00:03<00:00,  2.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# postgresql-17.4      | 5.4 MB    | : 100% 1.0/1 [00:03<00:00,  2.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# kaldi-5.5.1112       | 20.3 MB   | : 100% 1.0/1 [00:07<00:00,  1.71it/s]
#
# llvmlite-0.44.0      | 28.6 MB   | : 100% 1.0/1 [00:08<00:00,  1.42it/s]
# python-3.11.11       | 29.2 MB   | : 100% 1.0/1 [00:10<00:00,  1.26it/s]
#
#
#
#
#
# libopenvino-intel-cp | 11.8 MB   | : 100% 1.0/1 [00:10<00:00,  1.08it/s]
#
#
#
#
# scipy-1.15.2         | 16.4 MB   | : 100% 1.0/1 [00:12<00:00,  1.11it/s]
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:12<00:00,  1.91s/it]
#
#
#
#
#
#
#
# pillow-11.1.0        | 40.1 MB   | : 100% 1.0/1 [00:13<00:00,  1.06it/s]
#
#
#
#
#
#
#
#
# scikit-learn-1.6.1   | 10.2 MB   | : 100% 1.0/1 [00:14<00:00,  1.37s/it]
#
#
# libdb-6.2.32         | 23.3 MB   | : 100% 1.0/1 [00:15<00:00,  1.58it/s]
#
#
#
#
#
#
#
#
#
# ffmpeg-7.1.1         | 9.9 MB    | : 100% 1.0/1 [00:15<00:00,  1.46s/it]
#
#
#
#
#
#
#
#
#
#
# libopenvino-intel-gp | 9.7 MB    | : 100% 1.0/1 [00:16<00:00,  1.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.0 MB    | : 100% 1.0/1 [00:17<00:00,  2.41s/it]
#
#
#
#
#
#
#
#
#
#
#
# numpy-2.1.3          | 8.6 MB    | : 100% 1.0/1 [00:17<00:00,  2.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# librsvg-2.58.4       | 6.2 MB    | : 100% 1.0/1 [00:17<00:00,  3.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenvino-2025.0.0 | 5.4 MB    | : 100% 1.0/1 [00:18<00:00,  2.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.29   | 5.6 MB    | : 100% 1.0/1 [00:18<00:00,  2.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# postgresql-17.4      | 5.4 MB    | : 100% 1.0/1 [00:18<00:00,  2.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.61.0         | 5.7 MB    | : 100% 1.0/1 [00:19<00:00,  3.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# -
# |
# /
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate aligner
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# ======== DONE ==========
#
# To activate MFA, run: source /tmp/mfa/miniconda3/bin/activate aligner
#
# To delete MFA, run: rm -rf /tmp/mfa
#
# See: https://montreal-forced-aligner.readthedocs.io/en/latest/aligning.html to know how to use MFA
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /tmp/mfa/miniconda3/envs/aligner
#
#   added / updated specs:
#     - llvm-openmp
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     llvm-openmp-20.1.2         |       h024ca30_0         3.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-20.1.2-h024ca30_0
#
#
#
# Downloading and Extracting Packages: ...working...
# llvm-openmp-20.1.2   | 3.0 MB    |            |   0%
# llvm-openmp-20.1.2   | 3.0 MB    | #9         |  20%
# llvm-openmp-20.1.2   | 3.0 MB    | ########## | 100%
# llvm-openmp-20.1.2   | 3.0 MB    | ########## | 100%
# llvm-openmp-20.1.2   | 3.0 MB    | ########## | 100%
#
#  done
# done
# done
# done
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.1.1
#     latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
# !export MPLBACKEND=Agg && {INSTALL_DIR}/miniconda3/bin/conda run -n aligner mfa train --help
# Out:
#
#  Usage: mfa train [OPTIONS] CORPUS_DIRECTORY DICTIONARY_PATH OUTPUT_MODEL_PATH
#
#  Train a new acoustic model on a corpus and optionally export alignments
#
# ╭─ Options ────────────────────────────────────────────────────────────────────────────────────────╮
# │ --output_directory                    DIRECTORY                     Path to save alignments.     │
# │ --config_path                 -c      FILE                          Path to config file to use   │
# │                                                                     for training. See            │
# │                                                                     https://github.com/Montreal… │
# │                                                                     for examples.                │
# │ --speaker_characters          -s      TEXT                          Number of characters of file │
# │                                                                     names to use for determining │
# │                                                                     speaker, default is to use   │
# │                                                                     directory names.             │
# │ --audio_directory             -a      DIRECTORY                     Audio directory root to use  │
# │                                                                     for finding audio files.     │
# │ --phone_set                           [UNKNOWN|AUTO|MFA|IPA|ARPA|P  DEPRECATED, please use       │
# │                                       INYIN]                        --phone_groups_path to       │
# │                                                                     specify phone groups         │
# │                                                                     instead.                     │
# │ --phone_groups_path                   FILE                          Path to yaml file defining   │
# │                                                                     phone groups. See            │
# │                                                                     https://github.com/Montreal… │
# │                                                                     for examples.                │
# │ --rules_path                          FILE                          Path to yaml file defining   │
# │                                                                     phonological rules. See      │
# │                                                                     https://github.com/Montreal… │
# │                                                                     for examples.                │
# │ --topology_path                       FILE                          Path to yaml file defining   │
# │                                                                     topologies. See              │
# │                                                                     https://github.com/Montreal… │
# │                                                                     for examples.                │
# │ --output_format                       [long_textgrid|short_textgri  Format for aligned output    │
# │                                       d|json|csv]                   files (default is            │
# │                                                                     long_textgrid).              │
# │ --include_original_text                                             Flag to include original     │
# │                                                                     utterance text in the        │
# │                                                                     output.                      │
# │ --language                            [unknown|afrikaans|amharic|a  Language to use for spacy    │
# │                                       rabic|assamese|azerbaijani|b  tokenizers and other         │
# │                                       ashkir|belarusian|bulgarian|  preprocessing of language    │
# │                                       bengali|tibetan|breton|bosni  data.                        │
# │                                       an|catalan|czech|welsh|danis                               │
# │                                       h|german|greek|english|spani                               │
# │                                       sh|estonian|basque|farsi|fin                               │
# │                                       nish|faroese|french|galician                               │
# │                                       |gujarati|hausa|hebrew|hindi                               │
# │                                       |croatian|haitian|hungarian|                               │
# │                                       armenian|indonesian|icelandi                               │
# │                                       c|italian|japanese|georgian|                               │
# │                                       kazakh|central_khmer|kannada                               │
# │                                       |korean|latin|luxembourgish|                               │
# │                                       lingala|lao|lithuanian|latvi                               │
# │                                       an|malagasy|maori|macedonian                               │
# │                                       |malayalam|mongolian|marathi                               │
# │                                       |malay|maltese|burmese|nepal                               │
# │                                       i|dutch|norwegian_nynorsk|no                               │
# │                                       rwegian|occitan|punjabi|poli                               │
# │                                       sh|pashto|portuguese|romania                               │
# │                                       n|russian|sanskrit|sindhi|si                               │
# │                                       nhala|slovak|slovenian|shona                               │
# │                                       |somali|albanian|serbian|sun                               │
# │                                       danese|swedish|swahili|tamil                               │
# │                                       |telegu|tajik|thai|turkmen|t                               │
# │                                       agalog|turkish|tatar|ukraini                               │
# │                                       an|urdu|uzbek|vietnamese|yid                               │
# │                                       dish|yoruba|yue|chinese|kiny                               │
# │                                       arwanda|mandarin]                                          │
# │ --g2p_model_path                      FILE                          Path to G2P model to use for │
# │                                                                     OOV items.                   │
# │ --profile                     -p      TEXT                          Configuration profile to     │
# │                                                                     use, defaults to "global"    │
# │ --temporary_directory         -t      TEXT                          Set the default temporary    │
# │                                                                     directory, default is        │
# │                                                                     /root/Documents/MFA          │
# │ --num_jobs                    -j      INTEGER                       Set the number of processes  │
# │                                                                     to use by default, defaults  │
# │                                                                     to 3                         │
# │ --clean/--no_clean                                                  Remove files from previous   │
# │                                                                     runs, default is False       │
# │ --final_clean/--no_final_cle                                        Remove temporary files at    │
# │ an                                                                  the end of run, default is   │
# │                                                                     False                        │
# │ --verbose/--no_verbose        -v/-nv                                Output debug messages,       │
# │                                                                     default is False             │
# │ --quiet/--no_quiet            -q/-nq                                Suppress all output messages │
# │                                                                     (overrides verbose), default │
# │                                                                     is False                     │
# │ --overwrite/--no_overwrite                                          Overwrite output files when  │
# │                                                                     they exist, default is False │
# │ --use_mp/--no_use_mp                                                Turn on/off multiprocessing. │
# │                                                                     Multiprocessing is           │
# │                                                                     recommended will allow for   │
# │                                                                     faster executions.           │
# │ --use_threading/--no_use_thr                                        Use threading library rather │
# │ eading                                                              than multiprocessing         │
# │                                                                     library. Multiprocessing is  │
# │                                                                     recommended will allow for   │
# │                                                                     faster executions.           │
# │ --debug/--no_debug            -d/-nd                                Run extra steps for          │
# │                                                                     debugging issues, default is │
# │                                                                     False                        │
# │ --use_postgres/--no_use_post                                        Use postgres instead of      │
# │ gres                                                                sqlite for extra             │
# │                                                                     functionality, default is    │
# │                                                                     False                        │
# │ --single_speaker                                                    Single speaker mode creates  │
# │                                                                     multiprocessing splits based │
# │                                                                     on utterances rather than    │
# │                                                                     speakers. This mode also     │
# │                                                                     disables speaker adaptation  │
# │                                                                     equivalent to                │
# │                                                                     `--uses_speaker_adaptation   │
# │                                                                     false`.                      │
# │ --textgrid_cleanup/--no_text                                        Turn on/off post-processing  │
# │ grid_cleanup,--cleanup_textg                                        of TextGrids that cleans up  │
# │ rids/--no_cleanup_textgrids                                         silences and recombines      │
# │                                                                     compound words and clitics.  │
# │ --help                        -h                                    Show this message and exit.  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
import matplotlib
os.environ["MPLBACKEND"] = "Agg"
matplotlib.use("Agg")

# %%
# !export MPLBACKEND=Agg && {INSTALL_DIR}/miniconda3/bin/conda run -n aligner pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /tmp/mfa/miniconda3/envs/aligner/lib/python3.11/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /tmp/mfa/miniconda3/envs/aligner/lib/python3.11/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /tmp/mfa/miniconda3/envs/aligner/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /tmp/mfa/miniconda3/envs/aligner/lib/python3.11/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /tmp/mfa/miniconda3/envs/aligner/lib/python3.11/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in /tmp/mfa/miniconda3/envs/aligner/lib/python3.11/site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /tmp/mfa/miniconda3/envs/aligner/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /tmp/mfa/miniconda3/envs/aligner/lib/python3.11/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /tmp/mfa/miniconda3/envs/aligner/lib/python3.11/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /tmp/mfa/miniconda3/envs/aligner/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /tmp/mfa/miniconda3/envs/aligner/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
DATASET_PATH = "/content/drive/path/to/dataset" # path to audio datasets
AUDIO_PATH = f"{DATASET_PATH}/MFA_Output/MFA_align" # audio with word-level transcriptions per audio file
LEXICON_PATH = f"{DATASET_PATH}/Marungko_Pronunciation_Dictionary_CMU.txt"  # Phonetic lexicon
OUTPUT_PATH = f"{DATASET_PATH}/MFA_Output"

# %%
# !source {INSTALL_DIR}/miniconda3/bin/activate aligner && mfa version
# Out:
# 3.2.1

# %%
# VALIDATE
# !source {INSTALL_DIR}/miniconda3/bin/activate aligner; \
mfa validate $AUDIO_PATH $LEXICON_PATH
# Out:
#  INFO     Setting up corpus information...
#  INFO     Found 1 speaker across 6 files, average number of utterances per speaker: 6.0
#  INFO     Initializing multiprocessing jobs...
#  WARNING  Number of jobs was specified as 3, but due to only having 1 speakers, MFA will only use 1
#           jobs. Use the --single_speaker flag if you would like to split utterances across jobs
#           regardless of their speaker.
#  INFO     Text already normalized.
#  INFO     Features already generated.
#  INFO     Corpus
#  INFO     6 sound files
#  INFO     6 text files
#  INFO     1 speakers
#  INFO     6 utterances
#  INFO     92.225 seconds total duration
#  INFO     Sound file read errors
#  INFO     There were no issues reading sound files.
#  INFO     Feature generation
#  INFO     There were no utterances missing features.
#  INFO     Files without transcriptions
#  INFO     There were no sound files missing transcriptions.
#  INFO     Transcriptions without sound files
#  INFO     There were no transcription files missing sound files.
#  INFO     Dictionary
#  INFO     Out of vocabulary words
#  INFO     There were no missing words from the dictionary. If you plan on using the a model trained
#           on this dataset to align other datasets in the future, it is recommended that there be at
#           least some missing words.
#  INFO     Training
#  INFO     Initializing training for monophone...
#  INFO     Compiling training graphs...
#  INFO     Generating initial alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Initialization complete!
#  INFO     monophone - Iteration 1 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 2 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 3 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 4 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 5 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 6 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 7 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 8 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 9 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 10 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 11 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 12 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 13 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 14 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 15 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 16 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 17 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 18 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 19 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 20 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 21 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 22 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 23 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 24 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 25 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 26 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 27 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 28 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 29 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 30 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 31 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 32 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 33 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 34 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 35 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 36 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 37 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 38 of 40
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 39 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     monophone - Iteration 40 of 40
#  INFO     Accumulating statistics...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Training complete!
#  INFO     Compiling training graphs...
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Accumulating transition stats...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Finished accumulating transition stats!
#  INFO     Collecting phone and word alignments from monophone_ali lattices...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  WARNING  Alignment analysis not available without using postgresql
#  INFO     Beginning phone LM training...
#  INFO     Collecting training data...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Training model...
#  INFO     Completed training in 74.06902241706848 seconds!
#  INFO     Done! Everything took 74.509 seconds

# %%
# TRAIN
# !source {INSTALL_DIR}/miniconda3/bin/activate aligner && mfa train $AUDIO_PATH $LEXICON_PATH $OUTPUT_PATH/acoustic_model.zip --use_mp #--num_jobs 6 --single_speaker
# Out:
#  INFO     Using previous initialization.
#  INFO     Pronunciation probability estimation already done, loading saved probabilities...
#  INFO     Initializing training for sat_3...
#  INFO     Initialization complete!
#  INFO     sat_3 - Iteration 1 of 35
#  INFO     sat_3 - Iteration 2 of 35
#  INFO     sat_3 - Iteration 3 of 35
#  INFO     sat_3 - Iteration 4 of 35
#  INFO     sat_3 - Iteration 5 of 35
#  INFO     sat_3 - Iteration 6 of 35
#  INFO     sat_3 - Iteration 7 of 35
#  INFO     sat_3 - Iteration 8 of 35
#  INFO     sat_3 - Iteration 9 of 35
#  INFO     sat_3 - Iteration 10 of 35
#  INFO     sat_3 - Iteration 11 of 35
#  INFO     sat_3 - Iteration 12 of 35
#  INFO     sat_3 - Iteration 13 of 35
#  INFO     sat_3 - Iteration 14 of 35
#  INFO     sat_3 - Iteration 15 of 35
#  INFO     sat_3 - Iteration 16 of 35
#  INFO     sat_3 - Iteration 17 of 35
#  INFO     sat_3 - Iteration 18 of 35
#  INFO     sat_3 - Iteration 19 of 35
#  INFO     sat_3 - Iteration 20 of 35
#  INFO     sat_3 - Iteration 21 of 35
#  INFO     sat_3 - Iteration 22 of 35
#  INFO     sat_3 - Iteration 23 of 35
#  INFO     sat_3 - Iteration 24 of 35
#  INFO     sat_3 - Iteration 25 of 35
#  INFO     sat_3 - Iteration 26 of 35
#  INFO     sat_3 - Iteration 27 of 35
#  INFO     sat_3 - Iteration 28 of 35
#  INFO     sat_3 - Iteration 29 of 35
#  INFO     sat_3 - Iteration 30 of 35
#  INFO     sat_3 - Iteration 31 of 35
#  INFO     sat_3 - Iteration 32 of 35
#  INFO     sat_3 - Iteration 33 of 35
#  INFO     sat_3 - Iteration 34 of 35
#  INFO     sat_3 - Iteration 35 of 35
#  INFO     Creating alignment model for speaker-independent features...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3,888/3,336  [ 0:40:08 < 0:00:00 , 10 it/s ]
#  INFO     Training complete!
#  INFO     Exiting training early to save time as the corpus is below the subset size for later
#           training stages
#  INFO     Compiling training graphs...
#  INFO     Generating alignments...
#   98% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺ 3,282/3,336  [ 0:13:03 < 0:00:12 , 5 it/s ]
#  INFO     Calculating fMLLR for speaker adaptation...
#   98% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺ 3,282/3,336  [ 0:00:47 < 0:00:01 , 78 it/s ]
#  INFO     Generating alignments...
#   98% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺ 3,282/3,336  [ 0:13:57 < 0:00:14 , 4 it/s ]
#  INFO     Accumulating transition stats...
#   99% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺ 3,288/3,336  [ 0:00:04 < -:--:-- , ? it/s ]
#  INFO     Finished accumulating transition stats!
#  INFO     Collecting phone and word alignments from sat_3_ali lattices...
#   98% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺ 3,282/3,336  [ 0:00:10 < -:--:-- , ? it/s ]
#  WARNING  Alignment analysis not available without using postgresql
#  INFO     Beginning phone LM training...
#  INFO     Collecting training data...
#   98% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺ 3,282/3,336  [ 0:00:01 < 0:00:01 , 2,808 it/s ]
#  INFO     Training model...
#  INFO     Completed training in 4310.953010797501 seconds!
#  INFO     Saved model to /content/drive/My Drive/DP2/MFA_Output/acoustic_model.zip
#  INFO     Done! Everything took 4314.522 seconds

# %%
# Align the Data Using the Trained Model
# !source {INSTALL_DIR}/miniconda3/bin/activate aligner && mfa align $AUDIO_PATH $LEXICON_PATH $OUTPUT_PATH/acoustic_model.zip {OUTPUT_PATH}/MFA_results_add --beam 100 --retry_beam --400
# Out:
#  INFO     Setting up corpus information...
#  INFO     Found 1 speaker across 6 files, average number of utterances per speaker: 6.0
#  INFO     Initializing multiprocessing jobs...
#  WARNING  Number of jobs was specified as 3, but due to only having 1 speakers, MFA will only use 1
#           jobs. Use the --single_speaker flag if you would like to split utterances across jobs
#           regardless of their speaker.
#  INFO     Text already normalized.
#  INFO     Features already generated.
#  INFO     Compiling training graphs...
#  INFO     Performing first-pass alignment...
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:10 < 0:00:00 , ? it/s ]
#  INFO     Calculating fMLLR for speaker adaptation...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  INFO     Performing second-pass alignment...
#  INFO     Generating alignments...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:06 < 0:00:00 , ? it/s ]
#  INFO     Collecting phone and word alignments from alignment lattices...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:01 < 0:00:00 , ? it/s ]
#  WARNING  Alignment analysis not available without using postgresql
#  INFO     Exporting alignment TextGrids to /content/drive/My Drive/DP2/MFA_Output/MFA_results_add...
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6  [ 0:00:00 < 0:00:00 , ? it/s ]
#  INFO     Finished exporting TextGrids to /content/drive/My Drive/DP2/MFA_Output/MFA_results_add!
#  INFO     Done! Everything took 22.412 seconds

# %%
# Zip & Download Results (Trained Model + TextGrid Files)
# !zip -r {OUTPUT_PATH}/mfa_results.zip {OUTPUT_PATH}

# %% [markdown]
# ## To save and reload progress

# %%
# SAVE PROGRESS
import shutil

# Source and destination paths
src_path = "/root/Documents/MFA" #/BiRa_Dataset, /joblib_cache, /pretrained_models
backup_path = "/content/drive/path/to/backup"

# Backup
if os.path.exists(backup_path):
    print("Backup folder already exists in Drive, updating...")
    shutil.rmtree(backup_path)
shutil.copytree(src_path, backup_path)
print("MFA training directory successfully backed up to Google Drive.")
# Out:
# Backup folder already exists in Drive, updating...
# MFA training directory successfully backed up to Google Drive.

# %%
# RELOAD PROGRESS
import shutil

# Restore from backup
backup_path = "/content/drive/path/to/backup"
restore_path = "/root/Documents/MFA"

# Clean existing directory if needed
if os.path.exists(restore_path):
    print("Old MFA directory exists. Deleting before restore...")
    shutil.rmtree(restore_path)

# Restore from Drive
shutil.copytree(backup_path, restore_path)
print("MFA training directory successfully restored from Google Drive.")
# Out:
# Old MFA directory exists. Deleting before restore...
# MFA training directory successfully restored from Google Drive.
